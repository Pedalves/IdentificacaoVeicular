# %%
import requests
import json
import cv2
import matplotlib.pyplot as plt
import time

# %matplotlib inline

addr = 'http://localhost:5000'
test_url = addr + '/vehicle'

# prepare headers for http request
content_type = 'image/jpeg'
headers = {'content-type': content_type}

def predict(img):
    _, img_encoded = cv2.imencode('.jpg', img)
    
    start_time = time.time()
    response = requests.post(test_url, data=img_encoded.tostring(), headers=headers)
    # decode response
    print(json.loads(response.text), time.time() - start_time)

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.imshow(img)

# %%
img = cv2.imread('/home/pedalv/Documents/IV/CV001-05-14-12/0/004001056759520180514120535_L05.jpg')
predict(img)
# Out:
# {'license_plate': 'KXT8495'} 11.197627305984497

# %%
img = cv2.imread('/home/pedalv/Documents/IV/CV001-05-14-12/0/004001056756220180514120158_L04.jpg')
predict(img)
# Out:
# {'license_plate': 'KVS5251'} 11.006083965301514

# %%
img = cv2.imread('/home/pedalv/Documents/IV/CV001-05-14-12/0/004001056765620180514121106_L08.jpg')
predict(img)
# Out:
# {'license_plate': 'KWO9522'} 11.02285647392273

# %%
img = cv2.imread('/home/pedalv/Documents/IV/CV001-05-14-12/0/004001056813120180514125837_F01.jpg')
predict(img)
# Out:
# {'license_plate': 'KQQ7289'} 11.589994192123413

# %%
img = cv2.imread('/home/pedalv/Documents/IV/CV151-05-14-12/1_CV151-05-14-12/004151379390520180514120806_F01.jpg')
predict(img)
# Out:
# {'license_plate': 'KQW4803'} 10.652994155883789

# %%
img = cv2.imread('/home/pedalv/Documents/IV/CV151-05-14-12/1_CV151-05-14-12/004151379419920180514124421_L05.jpg')
predict(img)
# Out:
# {'license_plate': ''} 10.610066413879395
